# %%
import os
import sys
import pandas as pd
import numpy as np

# %%
# Set up paths
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
src_folder = os.path.join(project_root, 'src')

# %%
sys.path.insert(0, src_folder)
from s3_storage import *

# %%
test_array = np.random.rand(10,10)
test_array.sum()

# %%
test_df = pd.DataFrame(test_array)
test_df.sum().sum()

# %%
to_s3(test_array, 'mimic-jamesi', 'test_array.npy')
to_s3(test_df, 'mimic-jamesi', 'test_df.csv')

# %%
df_import = from_s3('mimic-jamesi', 'test_df.csv', index_col=0)
df_import.sum().sum()

# %%
arr_import = from_s3('mimic-jamesi', 'test_array.npy')
arr_import.sum()

# %%
arr_import

# %%
test_array

# %%
test = from_s3('mimic-jamesi', 'raw_data/D_ITEMS.csv')

# %%
test
# Out:
#        ROW_ID  ITEMID                                              LABEL  \
# 0         457     497        Patient controlled analgesia (PCA) [Inject]
# 1         458     498                                  PCA Lockout (Min)
# 2         459     499                                     PCA Medication
# 3         460     500                                     PCA Total Dose
# 4         461     501                                 PCV Exh Vt (Obser)
# 5        1157     927                                          Allergy 2
# 6        1158     930                                                Ext
# 7        1159     935                                          Allergy 3
# 8        1160     938                                     blood cultures
# 9        1161     940                                         trach care
# 10       1162     941                                      urine culture
# 11       1163     942                                     BLOOD CULTURES
# 12       1164     944                                           Chest PT
# 13       1165     946                                                STV
# 14       1166     956                                                CPT
# 15       1167     964                                         THAM CC/HR
# 16       1168     968                                                EKG
# 17       1169     970                                         TRACH CARE
# 18       1170     972                                   passy muir valve
# 19       1171     977                                        TRACHE CARE
# 20       1172     981                                           dilaudid
# 21       1173     983                                      LEECH THERAPY
# 22       1174     986                                            ABG Hct
# 23       1175     987                                 Clot to Blood Bank
# 24       1176     993                                   bladder pressure
# 25       1177     996                                   BLADDER PRESSURE
# 26       1178    1000                                      cisatricurium
# 27       1179    1001                                           rotation
# 28       1180    1003                                      cuff pressure
# 29       1181    1010                               High exhaled min vol
# ...       ...     ...                                                ...
# 12457   13701  225328           Tunneled (Hickman) Change over Wire Date
# 12458   13702  225329                 Tunneled (Hickman) Dressing Change
# 12459   13703  225330                  Tunneled (Hickman) Insertion Date
# 12460   13704  225331                     Tunneled (Hickman) Site Appear
# 12461   13705  225048                        Knee Location - Immobilizer
# 12462   13706  225050                              Warming Device Status
# 12463   13707  225052                              Cooling Device Status
# 12464   13708  225054                         Anti Embolic Device Status
# 12465   13709  225059                               Past medical history
# 12466   14502  226741  APACHE II Diagnosistic weight factors - Surgic...
# 12467   14503  226742   APACHE II Diagnosistic weight factors - Surgical
# 12468   14504  226743                                          APACHE II
# 12469   14505  226744                           APACHE II PDR - Adjusted
# 12470   14506  226745                    APACHE II Predecited Death Rate
# 12471   14507  226746                            ApacheII chronic health
# 12472   14508  226747                     APACHEII-Chronic health points
# 12473   14509  226748                             APACHEII-Renal failure
# 12474   14510  226749                                   ChpApacheIIScore
# 12475   14511  226750                                   Chronic Dilaysis
# 12476   14512  226751                            CreatinineApacheIIScore
# 12477   14513  226752                            CreatinineApacheIIValue
# 12478   14514  226753                                    DswfApacheScore
# 12479   14515  226754                                  FiO2ApacheIIValue
# 12480   14516  226755                                   GcsApacheIIScore
# 12481   14517  226756                                GCSEyeApacheIIValue
# 12482   14518  226757                              GCSMotorApacheIIValue
# 12483   14519  226758                             GCSVerbalApacheIIValue
# 12484   14520  226759                                  HCO3ApacheIIValue
# 12485   14521  226760                                          HCO3Score
# 12486   14522  226761                            HematocritApacheIIScore
#
#                                             ABBREVIATION    DBSOURCE  \
# 0                                                    NaN     carevue
# 1                                                    NaN     carevue
# 2                                                    NaN     carevue
# 3                                                    NaN     carevue
# 4                                                    NaN     carevue
# 5                                                    NaN     carevue
# 6                                                    NaN     carevue
# 7                                                    NaN     carevue
# 8                                                    NaN     carevue
# 9                                                    NaN     carevue
# 10                                                   NaN     carevue
# 11                                                   NaN     carevue
# 12                                                   NaN     carevue
# 13                                                   NaN     carevue
# 14                                                   NaN     carevue
# 15                                                   NaN     carevue
# 16                                                   NaN     carevue
# 17                                                   NaN     carevue
# 18                                                   NaN     carevue
# 19                                                   NaN     carevue
# 20                                                   NaN     carevue
# 21                                                   NaN     carevue
# 22                                                   NaN     carevue
# 23                                                   NaN     carevue
# 24                                                   NaN     carevue
# 25                                                   NaN     carevue
# 26                                                   NaN     carevue
# 27                                                   NaN     carevue
# 28                                                   NaN     carevue
# 29                                                   NaN     carevue
# ...                                                  ...         ...
# 12457           Tunneled (Hickman) Change over Wire Date  metavision
# 12458                 Tunneled (Hickman) Dressing Change  metavision
# 12459                  Tunneled (Hickman) Insertion Date  metavision
# 12460                     Tunneled (Hickman) Site Appear  metavision
# 12461                        Knee Location - Immobilizer  metavision
# 12462                              Warming Device Status  metavision
# 12463                              Cooling Device Status  metavision
# 12464                         Anti Embolic Device Status  metavision
# 12465                                                PMH  metavision
# 12466  Diagnosistic weight categories - Surgical emer...  metavision
# 12467          Diagnosistic weight categories - Surgical  metavision
# 12468                                          APACHE II  metavision
# 12469                           APACHE II PDR - Adjusted  metavision
# 12470                                      APACHE II PDR  metavision
# 12471                            ApacheII chronic health  metavision
# 12472                                       APACHEII-Chp  metavision
# 12473                             APACHEII-Renal failure  metavision
# 12474                                   ChpApacheIIScore  metavision
# 12475                                   Chronic Dilaysis  metavision
# 12476                            CreatinineApacheIIScore  metavision
# 12477                            CreatinineApacheIIValue  metavision
# 12478                                    DswfApacheScore  metavision
# 12479                                  FiO2ApacheIIValue  metavision
# 12480                                   GcsApacheIIScore  metavision
# 12481                                GCSEyeApacheIIValue  metavision
# 12482                              GCSMotorApacheIIValue  metavision
# 12483                             GCSVerbalApacheIIValue  metavision
# 12484                                  HCO3ApacheIIValue  metavision
# 12485                                          HCO3Score  metavision
# 12486                            HematocritApacheIIScore  metavision
#
#               LINKSTO                 CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 0         chartevents                      NaN      NaN        NaN        NaN
# 1         chartevents                      NaN      NaN        NaN        NaN
# 2         chartevents                      NaN      NaN        NaN        NaN
# 3         chartevents                      NaN      NaN        NaN        NaN
# 4         chartevents                      NaN      NaN        NaN        NaN
# 5         chartevents                      NaN      NaN        NaN        NaN
# 6         chartevents                      NaN      NaN        NaN        NaN
# 7         chartevents                      NaN      NaN        NaN        NaN
# 8         chartevents                      NaN      NaN        NaN        NaN
# 9         chartevents                      NaN      NaN        NaN        NaN
# 10        chartevents                      NaN      NaN        NaN        NaN
# 11        chartevents                      NaN      NaN        NaN        NaN
# 12        chartevents                      NaN      NaN        NaN        NaN
# 13        chartevents                      NaN      NaN        NaN        NaN
# 14        chartevents                      NaN      NaN        NaN        NaN
# 15        chartevents                      NaN      NaN        NaN        NaN
# 16        chartevents                      NaN      NaN        NaN        NaN
# 17        chartevents                      NaN      NaN        NaN        NaN
# 18        chartevents                      NaN      NaN        NaN        NaN
# 19        chartevents                      NaN      NaN        NaN        NaN
# 20        chartevents                      NaN      NaN        NaN        NaN
# 21        chartevents                      NaN      NaN        NaN        NaN
# 22        chartevents                      NaN      NaN        NaN        NaN
# 23        chartevents                      NaN      NaN        NaN        NaN
# 24        chartevents                      NaN      NaN        NaN        NaN
# 25        chartevents                      NaN      NaN        NaN        NaN
# 26        chartevents                      NaN      NaN        NaN        NaN
# 27        chartevents                      NaN      NaN        NaN        NaN
# 28        chartevents                      NaN      NaN        NaN        NaN
# 29        chartevents                      NaN      NaN        NaN        NaN
# ...               ...                      ...      ...        ...        ...
# 12457  datetimeevents  Access Lines - Invasive      NaN  Date time        NaN
# 12458  datetimeevents  Access Lines - Invasive      NaN  Date time        NaN
# 12459  datetimeevents  Access Lines - Invasive      NaN  Date time        NaN
# 12460     chartevents  Access Lines - Invasive      NaN       Text        NaN
# 12461     chartevents               Treatments      NaN       Text        NaN
# 12462     chartevents               Treatments      NaN       Text        NaN
# 12463     chartevents               Treatments      NaN       Text        NaN
# 12464     chartevents               Treatments      NaN       Text        NaN
# 12465     chartevents         Adm History/FHPA      NaN       Text        NaN
# 12466     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12467     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12468     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12469     chartevents       Scores - APACHE II        %    Numeric        NaN
# 12470     chartevents       Scores - APACHE II        %    Numeric        NaN
# 12471     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12472     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12473     chartevents       Scores - APACHE II      NaN   Checkbox        NaN
# 12474     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12475     chartevents   Scores - APACHE IV (2)      NaN   Checkbox        NaN
# 12476     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12477     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12478     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12479     chartevents       Scores - APACHE II        %    Numeric        NaN
# 12480     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12481     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12482     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12483     chartevents       Scores - APACHE II      NaN       Text        NaN
# 12484     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12485     chartevents       Scores - APACHE II     None    Numeric        NaN
# 12486     chartevents       Scores - APACHE II     None    Numeric        NaN
#
# [12487 rows x 10 columns]
