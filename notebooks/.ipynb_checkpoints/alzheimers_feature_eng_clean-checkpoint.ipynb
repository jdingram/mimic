# %%
# Import libraries
import os
import sys

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import statistics
import datetime as dt

from sklearn.preprocessing import MinMaxScaler, Imputer
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

import lightgbm as lgb

import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# /Users/James/anaconda3/envs/mimic/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)
# Using TensorFlow backend.

# %%
# Check virtual environment: should be: '/Users/James/anaconda3/envs/mimic/bin/python'
sys.executable
# Out:
# '/Users/James/anaconda3/envs/mimic/bin/python'

# %%
# Set up paths
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
src_folder = os.path.join(project_root, 'src')

src_preparation_folder = os.path.join(src_folder, 'preparation')
src_processing_folder = os.path.join(src_folder, 'processing')
src_modeling_folder = os.path.join(src_folder, 'modeling')

# %%
# Import src functions
sys.path.insert(0, src_preparation_folder)
from import_data import get_table
from import_data import get_patient_admissions_diagnoses
from import_data import get_admission_data
from import_data import get_chartevents
from import_data import get_labevents
from extract_codes import find_ndc_codes

sys.path.insert(0, src_processing_folder)
from stats import plot_KDE
from stats import plot_perc_bar_chart
from stats import compare_groups
from clean import replace_itemid_with_label
from clean import find_populated_cols

sys.path.insert(0, src_modeling_folder)
from models import train_lgb
# Out:
# /Users/James/anaconda3/envs/mimic/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# Import data
df = pd.read_csv(os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'data', 'chart_lab_events_df.csv')), index_col=0)

# %%
# Change headings
df = replace_itemid_with_label(df, ['subject_id', 'hadm_id', 'target'])

# %%
# Only keep populated cols
print(df.shape)
df = find_populated_cols(df, 'target', frac=0.75)
print(df.shape)
# Out:
# (4454, 1483)
# (4454, 28)

# %%
# Plot a KDE for all remaining cols
cols = [c for c in df.columns if c not in ['subject_id', 'hadm_id', 'target']]
for c in cols:
    plot_KDE(df, 'target', 1, 0, c)
# Out:
# /Users/James/Desktop/YourMD/machine_learning/mimic/src/processing/stats.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.dropna(inplace=True)
# /Users/James/anaconda3/envs/mimic/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Clean data ready for model

# Shuffle
df = df.sample(frac=1).reset_index(drop=True)

# Split features and labels
features = df.drop(columns=['subject_id', 'hadm_id', 'target'])
labels = np.array(df.target.tolist())

# Impute missing values
imputer = Imputer(strategy = 'median')
imputer.fit(features)
features = imputer.transform(features)

# Scale each feature to 0-1
scaler = MinMaxScaler(feature_range = (0, 1)) 
scaler.fit(features)
features = scaler.transform(features)
# Out:
# /Users/James/anaconda3/envs/mimic/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Hyperparameter grid
param_grid = {
    'boosting_type': ['gbdt', 'goss', 'dart'],
    'num_leaves': list(range(10, 150)),
    'learning_rate': list(np.linspace(0.001, 0.5)),
    'subsample_for_bin': list(range(20000, 300000, 20000)),
    'min_data_in_leaf': list(range(10, 250, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.001, 1)),
    'subsample': list(np.linspace(0.5, 1)),
    'is_unbalance': [True, False],
    'min_split_gain': list(np.linspace(0.001, 1)),
    'min_data_in_leaf': list(np.arange(1, 200, 3)),
}

# %%
# Train a Light GBM

df_cols = list(param_grid.keys())
df_cols = df_cols + ['training_score', 'valid_score']

runs_df = pd.DataFrame(columns=df_cols)
total_runs = 10000
run =0

while run < total_runs:
    
    run += 1
    
    # Select the random parameters
    random_params = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
    
    # Add constant params
    random_params['n_thread'] = 1
    random_params['n_estimators'] = 10000
    random_params['metric'] = 'auc'
    
    print('=========')
    print('RUN IS ' + str(run))
    print('=========')

    metrics, train_score, valid_score = train_lgb(features = features,
                                                 labels = labels,
                                                 n_folds = 5,
                                                 params = random_params,
                                                 eval_metric = 'auc',
                                                 early_stopping_rounds = 500)

    temp_df = pd.DataFrame(columns=df_cols)

    for c in list(param_grid.keys()):
        temp_df.loc[0, c] = random_params[c]
    
    temp_df.loc[0, 'training_score'] = train_score
    temp_df.loc[0, 'valid_score'] = valid_score
    
    runs_df = runs_df.append(temp_df)

    del temp_df, train_score, valid_score
# Out:
# =========
# RUN IS 1
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.608053	train's auc: 0.998978
# Early stopping, best iteration is:
# [12]	valid's auc: 0.655952	train's auc: 0.945688
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.648311	train's auc: 0.998892
# Early stopping, best iteration is:
# [11]	valid's auc: 0.664645	train's auc: 0.939585
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.638127	train's auc: 0.99902
# Early stopping, best iteration is:
# [13]	valid's auc: 0.653333	train's auc: 0.954625
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.666561	train's auc: 0.99812
# Early stopping, best iteration is:
# [15]	valid's auc: 0.70002	train's auc: 0.954049
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.612548	train's auc: 0.999395
# Early stopping, best iteration is:
# [14]	valid's auc: 0.652135	train's auc: 0.954988
#       fold     train     valid
# 0        0  0.945688  0.655952
# 1        1  0.939585  0.664645
# 2        2  0.954625  0.653333
# 3        3  0.954049  0.700020
# 4        4  0.954988  0.652135
# 5  overall  0.949787  0.663140
# =========
# RUN IS 2
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.577824	train's auc: 0.999944
# Early stopping, best iteration is:
# [10]	valid's auc: 0.613399	train's auc: 0.945923
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.61031	train's auc: 0.999981
# Early stopping, best iteration is:
# [19]	valid's auc: 0.65161	train's auc: 0.984746
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.595978	train's auc: 0.999969
# Early stopping, best iteration is:
# [6]	valid's auc: 0.651221	train's auc: 0.927391
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.58495	train's auc: 0.999943
# Early stopping, best iteration is:
# [4]	valid's auc: 0.638939	train's auc: 0.890955
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.583106	train's auc: 1
# Early stopping, best iteration is:
# [2]	valid's auc: 0.602622	train's auc: 0.883726
#       fold     train     valid
# 0        0  0.945923  0.613399
# 1        1  0.984746  0.651610
# 2        2  0.927391  0.651221
# 3        3  0.890955  0.638939
# 4        4  0.883726  0.602622
# 5  overall  0.926548  0.627834
# =========
# RUN IS 3
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630042	train's auc: 0.874181
# Early stopping, best iteration is:
# [131]	valid's auc: 0.647199	train's auc: 0.83341
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.684397	train's auc: 0.875153
# Early stopping, best iteration is:
# [365]	valid's auc: 0.6889	train's auc: 0.860252
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.671148	train's auc: 0.878684
# Early stopping, best iteration is:
# [220]	valid's auc: 0.684334	train's auc: 0.845651
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.68414	train's auc: 0.87464
# Early stopping, best iteration is:
# [202]	valid's auc: 0.697314	train's auc: 0.837115
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.645294	train's auc: 0.880328
# Early stopping, best iteration is:
# [5]	valid's auc: 0.661525	train's auc: 0.767584
#       fold     train     valid
# 0        0  0.833410  0.647199
# 1        1  0.860252  0.688900
# 2        2  0.845651  0.684334
# 3        3  0.837115  0.697314
# 4        4  0.767584  0.661525
# 5  overall  0.828802  0.662646
# =========
# RUN IS 4
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.633497	train's auc: 0.979305
# Early stopping, best iteration is:
# [4]	valid's auc: 0.656583	train's auc: 0.857704
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.658147	train's auc: 0.98002
# Early stopping, best iteration is:
# [11]	valid's auc: 0.680644	train's auc: 0.942345
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.620588	train's auc: 0.981653
# Early stopping, best iteration is:
# [4]	valid's auc: 0.670239	train's auc: 0.846293
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.631503	train's auc: 0.971747
# Early stopping, best iteration is:
# [4]	valid's auc: 0.67141	train's auc: 0.856761
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.610385	train's auc: 0.982745
# Early stopping, best iteration is:
# [3]	valid's auc: 0.670369	train's auc: 0.837179
#       fold     train     valid
# 0        0  0.857704  0.656583
# 1        1  0.942345  0.680644
# 2        2  0.846293  0.670239
# 3        3  0.856761  0.671410
# 4        4  0.837179  0.670369
# 5  overall  0.868056  0.667589
# =========
# RUN IS 5
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.598366	train's auc: 0.981948
# Early stopping, best iteration is:
# [35]	valid's auc: 0.627451	train's auc: 0.892696
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.553032	train's auc: 0.986984
# Early stopping, best iteration is:
# [9]	valid's auc: 0.621924	train's auc: 0.751154
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614913	train's auc: 0.985718
# Early stopping, best iteration is:
# [35]	valid's auc: 0.663949	train's auc: 0.885822
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.624412	train's auc: 0.985038
# Early stopping, best iteration is:
# [297]	valid's auc: 0.629133	train's auc: 0.977338
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630053	train's auc: 0.986734
# Early stopping, best iteration is:
# [56]	valid's auc: 0.643333	train's auc: 0.921168
#       fold     train     valid
# 0        0  0.892696  0.627451
# 1        1  0.751154  0.621924
# 2        2  0.885822  0.663949
# 3        3  0.977338  0.629133
# 4        4  0.921168  0.643333
# 5  overall  0.885636  0.619501
# =========
# RUN IS 6
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.582796	train's auc: 0.974143
# Early stopping, best iteration is:
# [10]	valid's auc: 0.635504	train's auc: 0.816955
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.594489	train's auc: 0.979685
# Early stopping, best iteration is:
# [24]	valid's auc: 0.661347	train's auc: 0.874931
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.62314	train's auc: 0.978155
# Early stopping, best iteration is:
# [41]	valid's auc: 0.643912	train's auc: 0.921821
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.623524	train's auc: 0.97245
# Early stopping, best iteration is:
# [69]	valid's auc: 0.636283	train's auc: 0.944814
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.613186	train's auc: 0.980368
# Early stopping, best iteration is:
# [80]	valid's auc: 0.628527	train's auc: 0.95399
#       fold     train     valid
# 0        0  0.816955  0.635504
# 1        1  0.874931  0.661347
# 2        2  0.921821  0.643912
# 3        3  0.944814  0.636283
# 4        4  0.953990  0.628527
# 5  overall  0.902502  0.633685
# =========
# RUN IS 7
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.584734	train's auc: 0.988894
# Early stopping, best iteration is:
# [17]	valid's auc: 0.674907	train's auc: 0.831179
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.589117	train's auc: 0.989882
# Early stopping, best iteration is:
# [58]	valid's auc: 0.656567	train's auc: 0.866137
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.609017	train's auc: 0.989947
# Early stopping, best iteration is:
# [48]	valid's auc: 0.662571	train's auc: 0.872165
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.6286	train's auc: 0.989577
# Early stopping, best iteration is:
# [25]	valid's auc: 0.678906	train's auc: 0.842716
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.556899	train's auc: 0.992758
# Early stopping, best iteration is:
# [75]	valid's auc: 0.625241	train's auc: 0.904382
#       fold     train     valid
# 0        0  0.831179  0.674907
# 1        1  0.866137  0.656567
# 2        2  0.872165  0.662571
# 3        3  0.842716  0.678906
# 4        4  0.904382  0.625241
# 5  overall  0.863316  0.654495
# =========
# RUN IS 8
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.593651	train's auc: 0.998488
# Early stopping, best iteration is:
# [11]	valid's auc: 0.626704	train's auc: 0.875714
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.621489	train's auc: 0.999296
# Early stopping, best iteration is:
# [113]	valid's auc: 0.637428	train's auc: 0.996362
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.622571	train's auc: 0.999228
# Early stopping, best iteration is:
# [9]	valid's auc: 0.649587	train's auc: 0.847493
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.625834	train's auc: 0.998917
# Early stopping, best iteration is:
# [19]	valid's auc: 0.667154	train's auc: 0.92791
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.605188	train's auc: 0.999187
# Early stopping, best iteration is:
# [15]	valid's auc: 0.610771	train's auc: 0.911943
#       fold     train     valid
# 0        0  0.875714  0.626704
# 1        1  0.996362  0.637428
# 2        2  0.847493  0.649587
# 3        3  0.927910  0.667154
# 4        4  0.911943  0.610771
# 5  overall  0.911885  0.633344
# =========
# RUN IS 9
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.612418	train's auc: 0.95498
# Early stopping, best iteration is:
# [6]	valid's auc: 0.658438	train's auc: 0.860125
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.667569	train's auc: 0.953075
# Early stopping, best iteration is:
# [27]	valid's auc: 0.682955	train's auc: 0.911228
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.651129	train's auc: 0.956876
# Early stopping, best iteration is:
# [6]	valid's auc: 0.675197	train's auc: 0.864419
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.653842	train's auc: 0.957899
# Early stopping, best iteration is:
# [124]	valid's auc: 0.671558	train's auc: 0.912495
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.634496	train's auc: 0.964028
# Early stopping, best iteration is:
# [50]	valid's auc: 0.649805	train's auc: 0.925386
#       fold     train     valid
# 0        0  0.860125  0.658438
# 1        1  0.911228  0.682955
# 2        2  0.864419  0.675197
# 3        3  0.912495  0.671558
# 4        4  0.925386  0.649805
# 5  overall  0.894730  0.617521
# =========
# RUN IS 10
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.554085	train's auc: 0.998182
# Early stopping, best iteration is:
# [91]	valid's auc: 0.641807	train's auc: 0.921204
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.572743	train's auc: 0.998447
# Early stopping, best iteration is:
# [26]	valid's auc: 0.682244	train's auc: 0.847077
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.579082	train's auc: 0.994676
# Early stopping, best iteration is:
# [17]	valid's auc: 0.670744	train's auc: 0.826972
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.580407	train's auc: 0.997759
# Early stopping, best iteration is:
# [19]	valid's auc: 0.688663	train's auc: 0.824323
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.531765	train's auc: 0.999215
# Early stopping, best iteration is:
# [1]	valid's auc: 0.659924	train's auc: 0.732764
#       fold     train     valid
# 0        0  0.921204  0.641807
# 1        1  0.847077  0.682244
# 2        2  0.826972  0.670744
# 3        3  0.824323  0.688663
# 4        4  0.732764  0.659924
# 5  overall  0.830468  0.663508
# =========
# RUN IS 11
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.562745	train's auc: 0.999964
# Early stopping, best iteration is:
# [2]	valid's auc: 0.581162	train's auc: 0.763749
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.582204	train's auc: 0.999986
# Early stopping, best iteration is:
# [1]	valid's auc: 0.622003	train's auc: 0.708557
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.59214	train's auc: 0.999712
# Early stopping, best iteration is:
# [8]	valid's auc: 0.657374	train's auc: 0.888495
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.60241	train's auc: 0.999937
# Early stopping, best iteration is:
# [61]	valid's auc: 0.608197	train's auc: 0.999933
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.609916	train's auc: 0.999969
# Early stopping, best iteration is:
# [9]	valid's auc: 0.637196	train's auc: 0.915178
#       fold     train     valid
# 0        0  0.763749  0.581162
# 1        1  0.708557  0.622003
# 2        2  0.888495  0.657374
# 3        3  0.999933  0.608197
# 4        4  0.915178  0.637196
# 5  overall  0.855182  0.598451
# =========
# RUN IS 12
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.627334	train's auc: 0.951843
# Early stopping, best iteration is:
# [87]	valid's auc: 0.611648	train's auc: 0.958425
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.618941	train's auc: 0.941022
# Early stopping, best iteration is:
# [22]	valid's auc: 0.594667	train's auc: 0.956291
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.665069	train's auc: 0.937966
# Early stopping, best iteration is:
# [31]	valid's auc: 0.64595	train's auc: 0.952349
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.635572	train's auc: 0.921819
# Early stopping, best iteration is:
# [6]	valid's auc: 0.65952	train's auc: 0.894742
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.659295	train's auc: 0.947056
# Early stopping, best iteration is:
# [70]	valid's auc: 0.634278	train's auc: 0.96431
#       fold     train     valid
# 0        0  0.958425  0.611648
# 1        1  0.956291  0.594667
# 2        2  0.952349  0.645950
# 3        3  0.894742  0.659520
# 4        4  0.964310  0.634278
# 5  overall  0.945223  0.545115
# =========
# RUN IS 13
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.595985	train's auc: 0.999885
# Early stopping, best iteration is:
# [19]	valid's auc: 0.591013	train's auc: 0.999898
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.613411	train's auc: 0.999928
# Early stopping, best iteration is:
# [29]	valid's auc: 0.613016	train's auc: 0.999928
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614233	train's auc: 0.999933
# Early stopping, best iteration is:
# [6]	valid's auc: 0.620165	train's auc: 0.997011
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.638692	train's auc: 0.999895
# Early stopping, best iteration is:
# [18]	valid's auc: 0.642346	train's auc: 0.999901
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.596502	train's auc: 0.999945
# Early stopping, best iteration is:
# [22]	valid's auc: 0.594038	train's auc: 0.999945
#       fold     train     valid
# 0        0  0.999898  0.591013
# 1        1  0.999928  0.613016
# 2        2  0.997011  0.620165
# 3        3  0.999901  0.642346
# 4        4  0.999945  0.594038
# 5  overall  0.999337  0.608374
# =========
# RUN IS 14
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.618324	train's auc: 0.999979
# Early stopping, best iteration is:
# [10]	valid's auc: 0.666737	train's auc: 0.947819
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.637784	train's auc: 0.999966
# Early stopping, best iteration is:
# [9]	valid's auc: 0.676338	train's auc: 0.944811
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.651019	train's auc: 0.999871
# Early stopping, best iteration is:
# [5]	valid's auc: 0.694086	train's auc: 0.901672
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.645803	train's auc: 0.999921
# Early stopping, best iteration is:
# [33]	valid's auc: 0.647541	train's auc: 0.998294
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.592579	train's auc: 0.999768
# Early stopping, best iteration is:
# [10]	valid's auc: 0.638051	train's auc: 0.963535
#       fold     train     valid
# 0        0  0.947819  0.666737
# 1        1  0.944811  0.676338
# 2        2  0.901672  0.694086
# 3        3  0.998294  0.647541
# 4        4  0.963535  0.638051
# 5  overall  0.951226  0.658224
# =========
# RUN IS 15
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.517017	train's auc: 0.993025
# Early stopping, best iteration is:
# [13]	valid's auc: 0.626517	train's auc: 0.805261
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.5492	train's auc: 0.995132
# Early stopping, best iteration is:
# [8]	valid's auc: 0.65555	train's auc: 0.786871
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.578861	train's auc: 0.995116
# Early stopping, best iteration is:
# [3]	valid's auc: 0.679899	train's auc: 0.772136
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.646909	train's auc: 0.997379
# Early stopping, best iteration is:
# [53]	valid's auc: 0.69603	train's auc: 0.872729
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.55492	train's auc: 0.996147
# Early stopping, best iteration is:
# [1]	valid's auc: 0.655028	train's auc: 0.727057
#       fold     train     valid
# 0        0  0.805261  0.626517
# 1        1  0.786871  0.655550
# 2        2  0.772136  0.679899
# 3        3  0.872729  0.696030
# 4        4  0.727057  0.655028
# 5  overall  0.792811  0.662024
# =========
# RUN IS 16
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.53296	train's auc: 0.999988
# Early stopping, best iteration is:
# [15]	valid's auc: 0.650444	train's auc: 0.865658
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.588623	train's auc: 0.999988
# Early stopping, best iteration is:
# [45]	valid's auc: 0.649674	train's auc: 0.932435
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.620735	train's auc: 0.999989
# Early stopping, best iteration is:
# [46]	valid's auc: 0.689146	train's auc: 0.929411
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.589789	train's auc: 0.999987
# Early stopping, best iteration is:
# [28]	valid's auc: 0.630002	train's auc: 0.910706
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.571654	train's auc: 1
# Early stopping, best iteration is:
# [19]	valid's auc: 0.615919	train's auc: 0.901191
#       fold     train     valid
# 0        0  0.865658  0.650444
# 1        1  0.932435  0.649674
# 2        2  0.929411  0.689146
# 3        3  0.910706  0.630002
# 4        4  0.901191  0.615919
# 5  overall  0.907880  0.643142
# =========
# RUN IS 17
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.622012	train's auc: 0.999988
# Early stopping, best iteration is:
# [13]	valid's auc: 0.631699	train's auc: 0.990669
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630298	train's auc: 0.99999
# Early stopping, best iteration is:
# [41]	valid's auc: 0.654059	train's auc: 0.999988
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.628944	train's auc: 0.999989
# Early stopping, best iteration is:
# [12]	valid's auc: 0.692893	train's auc: 0.99051
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.641122	train's auc: 0.999989
# Early stopping, best iteration is:
# [35]	valid's auc: 0.635769	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.610067	train's auc: 1
# Early stopping, best iteration is:
# [21]	valid's auc: 0.620429	train's auc: 0.999149
#       fold     train     valid
# 0        0  0.990669  0.631699
# 1        1  0.999988  0.654059
# 2        2  0.990510  0.692893
# 3        3  0.999989  0.635769
# 4        4  0.999149  0.620429
# 5  overall  0.996061  0.637677
# =========
# RUN IS 18
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.626891	train's auc: 0.998495
# Early stopping, best iteration is:
# [11]	valid's auc: 0.629575	train's auc: 0.998066
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.639087	train's auc: 0.999316
# Early stopping, best iteration is:
# [14]	valid's auc: 0.642899	train's auc: 0.999176
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.597649	train's auc: 0.999072
# Early stopping, best iteration is:
# [4]	valid's auc: 0.642975	train's auc: 0.961533
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.644243	train's auc: 0.998018
# Early stopping, best iteration is:
# [11]	valid's auc: 0.645842	train's auc: 0.997091
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.625476	train's auc: 0.998789
# Early stopping, best iteration is:
# [12]	valid's auc: 0.628209	train's auc: 0.998601
#       fold     train     valid
# 0        0  0.998066  0.629575
# 1        1  0.999176  0.642899
# 2        2  0.961533  0.642975
# 3        3  0.997091  0.645842
# 4        4  0.998601  0.628209
# 5  overall  0.990893  0.632771
# =========
# RUN IS 19
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.572479	train's auc: 0.98278
# Early stopping, best iteration is:
# [12]	valid's auc: 0.659582	train's auc: 0.798917
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614695	train's auc: 0.98368
# Early stopping, best iteration is:
# [29]	valid's auc: 0.658325	train's auc: 0.821673
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.610781	train's auc: 0.985775
# Early stopping, best iteration is:
# [94]	valid's auc: 0.666152	train's auc: 0.892757
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.612838	train's auc: 0.985124
# Early stopping, best iteration is:
# [46]	valid's auc: 0.681236	train's auc: 0.846788
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.578629	train's auc: 0.989337
# Early stopping, best iteration is:
# [118]	valid's auc: 0.619356	train's auc: 0.914851
#       fold     train     valid
# 0        0  0.798917  0.659582
# 1        1  0.821673  0.658325
# 2        2  0.892757  0.666152
# 3        3  0.846788  0.681236
# 4        4  0.914851  0.619356
# 5  overall  0.854997  0.649522
# =========
# RUN IS 20
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.574767	train's auc: 0.961009
# Early stopping, best iteration is:
# [54]	valid's auc: 0.57549	train's auc: 0.972755
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630496	train's auc: 0.981639
# Early stopping, best iteration is:
# [70]	valid's auc: 0.605096	train's auc: 0.985967
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.650964	train's auc: 0.959741
# Early stopping, best iteration is:
# [35]	valid's auc: 0.584904	train's auc: 0.973946
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.63014	train's auc: 0.964349
# Early stopping, best iteration is:
# [102]	valid's auc: 0.640154	train's auc: 0.959803
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.631462	train's auc: 0.967954
# Early stopping, best iteration is:
# [5]	valid's auc: 0.674251	train's auc: 0.879382
#       fold     train     valid
# 0        0  0.972755  0.575490
# 1        1  0.985967  0.605096
# 2        2  0.973946  0.584904
# 3        3  0.959803  0.640154
# 4        4  0.879382  0.674251
# 5  overall  0.954371  0.540880
# =========
# RUN IS 21
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.511345	train's auc: 0.612534
# Early stopping, best iteration is:
# [6]	valid's auc: 0.663329	train's auc: 0.811799
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.618487	train's auc: 0.93898
# Early stopping, best iteration is:
# [6]	valid's auc: 0.658147	train's auc: 0.81134
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.626887	train's auc: 0.922191
# Early stopping, best iteration is:
# [17]	valid's auc: 0.673976	train's auc: 0.895825
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.640648	train's auc: 0.946155
# Early stopping, best iteration is:
# [142]	valid's auc: 0.662572	train's auc: 0.930578
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.611291	train's auc: 0.941119
# Early stopping, best iteration is:
# [4]	valid's auc: 0.625602	train's auc: 0.783591
#       fold     train     valid
# 0        0  0.811799  0.663329
# 1        1  0.811340  0.658147
# 2        2  0.895825  0.673976
# 3        3  0.930578  0.662572
# 4        4  0.783591  0.625602
# 5  overall  0.846627  0.534188
# =========
# RUN IS 22
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.581046	train's auc: 0.999984
# Early stopping, best iteration is:
# [10]	valid's auc: 0.589192	train's auc: 0.990824
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.563065	train's auc: 0.99999
# Early stopping, best iteration is:
# [1]	valid's auc: 0.618201	train's auc: 0.791671
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.591258	train's auc: 0.999987
# Early stopping, best iteration is:
# [6]	valid's auc: 0.621635	train's auc: 0.971172
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.563855	train's auc: 0.999989
# Early stopping, best iteration is:
# [5]	valid's auc: 0.579103	train's auc: 0.947962
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.594775	train's auc: 1
# Early stopping, best iteration is:
# [5]	valid's auc: 0.61778	train's auc: 0.950061
#       fold     train     valid
# 0        0  0.990824  0.589192
# 1        1  0.791671  0.618201
# 2        2  0.971172  0.621635
# 3        3  0.947962  0.579103
# 4        4  0.950061  0.617780
# 5  overall  0.930338  0.602929
# =========
# RUN IS 23
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.605929	train's auc: 0.999919
# Early stopping, best iteration is:
# [64]	valid's auc: 0.620822	train's auc: 0.999473
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.609698	train's auc: 0.999971
# Early stopping, best iteration is:
# [46]	valid's auc: 0.645981	train's auc: 0.998979
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.61719	train's auc: 0.999945
# Early stopping, best iteration is:
# [8]	valid's auc: 0.628834	train's auc: 0.982691
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.640213	train's auc: 0.999951
# Early stopping, best iteration is:
# [117]	valid's auc: 0.64683	train's auc: 0.999962
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.602019	train's auc: 1
# Early stopping, best iteration is:
# [12]	valid's auc: 0.617243	train's auc: 0.989844
#       fold     train     valid
# 0        0  0.999473  0.620822
# 1        1  0.998979  0.645981
# 2        2  0.982691  0.628834
# 3        3  0.999962  0.646830
# 4        4  0.989844  0.617243
# 5  overall  0.994190  0.630642
# =========
# RUN IS 24
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630976	train's auc: 0.992827
# Early stopping, best iteration is:
# [23]	valid's auc: 0.662138	train's auc: 0.995708
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.616413	train's auc: 0.99029
# Early stopping, best iteration is:
# [41]	valid's auc: 0.633834	train's auc: 0.996443
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.621763	train's auc: 0.99368
# Early stopping, best iteration is:
# [34]	valid's auc: 0.621965	train's auc: 0.997169
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.632767	train's auc: 0.9907
# Early stopping, best iteration is:
# [39]	valid's auc: 0.614853	train's auc: 0.995733
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.642293	train's auc: 0.994569
# Early stopping, best iteration is:
# [38]	valid's auc: 0.620815	train's auc: 0.998808
#       fold     train     valid
# 0        0  0.995708  0.662138
# 1        1  0.996443  0.633834
# 2        2  0.997169  0.621965
# 3        3  0.995733  0.614853
# 4        4  0.998808  0.620815
# 5  overall  0.996772  0.522622
# =========
# RUN IS 25
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.58366	train's auc: 0.999986
# Early stopping, best iteration is:
# [92]	valid's auc: 0.559617	train's auc: 0.999988
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.59682	train's auc: 0.99999
# Early stopping, best iteration is:
# [11]	valid's auc: 0.63413	train's auc: 0.972134
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.596694	train's auc: 0.999987
# Early stopping, best iteration is:
# [8]	valid's auc: 0.655464	train's auc: 0.945029
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.635374	train's auc: 0.999987
# Early stopping, best iteration is:
# [146]	valid's auc: 0.605906	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.607854	train's auc: 1
# Early stopping, best iteration is:
# [37]	valid's auc: 0.558441	train's auc: 1
#       fold     train     valid
# 0        0  0.999988  0.559617
# 1        1  0.972134  0.634130
# 2        2  0.945029  0.655464
# 3        3  0.999989  0.605906
# 4        4  1.000000  0.558441
# 5  overall  0.983428  0.593055
# =========
# RUN IS 26
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.606699	train's auc: 0.998559
# Early stopping, best iteration is:
# [33]	valid's auc: 0.646359	train's auc: 0.9622
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.607723	train's auc: 0.999555
# Early stopping, best iteration is:
# [8]	valid's auc: 0.671223	train's auc: 0.942325
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.639706	train's auc: 0.99902
# Early stopping, best iteration is:
# [23]	valid's auc: 0.668815	train's auc: 0.962869
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.631977	train's auc: 0.998876
# Early stopping, best iteration is:
# [18]	valid's auc: 0.674679	train's auc: 0.943309
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.570698	train's auc: 0.999402
# Early stopping, best iteration is:
# [46]	valid's auc: 0.614996	train's auc: 0.977727
#       fold     train     valid
# 0        0  0.962200  0.646359
# 1        1  0.942325  0.671223
# 2        2  0.962869  0.668815
# 3        3  0.943309  0.674679
# 4        4  0.977727  0.614996
# 5  overall  0.957686  0.644106
# =========
# RUN IS 27
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.65077	train's auc: 0.913327
# Early stopping, best iteration is:
# [10]	valid's auc: 0.665091	train's auc: 0.816683
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.682619	train's auc: 0.91458
# Early stopping, best iteration is:
# [402]	valid's auc: 0.684318	train's auc: 0.903498
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.677466	train's auc: 0.919801
# Early stopping, best iteration is:
# [259]	valid's auc: 0.683306	train's auc: 0.89124
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.68017	train's auc: 0.918083
# Early stopping, best iteration is:
# [343]	valid's auc: 0.685127	train's auc: 0.901168
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.645026	train's auc: 0.928931
# Early stopping, best iteration is:
# [242]	valid's auc: 0.660267	train's auc: 0.90273
#       fold     train     valid
# 0        0  0.816683  0.665091
# 1        1  0.903498  0.684318
# 2        2  0.891240  0.683306
# 3        3  0.901168  0.685127
# 4        4  0.902730  0.660267
# 5  overall  0.883064  0.649088
# =========
# RUN IS 28
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.58233	train's auc: 0.951141
# Early stopping, best iteration is:
# [6]	valid's auc: 0.621569	train's auc: 0.864366
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.62619	train's auc: 0.951756
# Early stopping, best iteration is:
# [68]	valid's auc: 0.601659	train's auc: 0.957127
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.618384	train's auc: 0.945363
# Early stopping, best iteration is:
# [9]	valid's auc: 0.667456	train's auc: 0.877782
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.639463	train's auc: 0.933708
# Early stopping, best iteration is:
# [8]	valid's auc: 0.664369	train's auc: 0.860151
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.628427	train's auc: 0.9518
# Early stopping, best iteration is:
# [146]	valid's auc: 0.641153	train's auc: 0.954038
#       fold     train     valid
# 0        0  0.864366  0.621569
# 1        1  0.957127  0.601659
# 2        2  0.877782  0.667456
# 3        3  0.860151  0.664369
# 4        4  0.954038  0.641153
# 5  overall  0.902693  0.500795
# =========
# RUN IS 29
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.530602	train's auc: 0.99993
# Early stopping, best iteration is:
# [10]	valid's auc: 0.610714	train's auc: 0.799995
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.57223	train's auc: 0.999983
# Early stopping, best iteration is:
# [11]	valid's auc: 0.673494	train's auc: 0.814405
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.592066	train's auc: 0.999969
# Early stopping, best iteration is:
# [30]	valid's auc: 0.63067	train's auc: 0.902141
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.580249	train's auc: 0.999958
# Early stopping, best iteration is:
# [10]	valid's auc: 0.632096	train's auc: 0.802471
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.578193	train's auc: 1
# Early stopping, best iteration is:
# [31]	valid's auc: 0.639292	train's auc: 0.90103
#       fold     train     valid
# 0        0  0.799995  0.610714
# 1        1  0.814405  0.673494
# 2        2  0.902141  0.630670
# 3        3  0.802471  0.632096
# 4        4  0.901030  0.639292
# 5  overall  0.844009  0.633404
# =========
# RUN IS 30
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.632703	train's auc: 0.846628
# [1000]	valid's auc: 0.636975	train's auc: 0.893783
# [1500]	valid's auc: 0.639939	train's auc: 0.932813
# Early stopping, best iteration is:
# [1354]	valid's auc: 0.647129	train's auc: 0.922522
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.666285	train's auc: 0.851138
# Early stopping, best iteration is:
# [35]	valid's auc: 0.667509	train's auc: 0.805109
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.667695	train's auc: 0.842787
# [1000]	valid's auc: 0.663673	train's auc: 0.903343
# Early stopping, best iteration is:
# [655]	valid's auc: 0.670064	train's auc: 0.86598
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.678313	train's auc: 0.850574
# [1000]	valid's auc: 0.683745	train's auc: 0.897247
# Early stopping, best iteration is:
# [872]	valid's auc: 0.686865	train's auc: 0.889939
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.665063	train's auc: 0.864551
# Early stopping, best iteration is:
# [409]	valid's auc: 0.669623	train's auc: 0.847224
#       fold     train     valid
# 0        0  0.922522  0.647129
# 1        1  0.805109  0.667509
# 2        2  0.865980  0.670064
# 3        3  0.889939  0.686865
# 4        4  0.847224  0.669623
# 5  overall  0.866155  0.620370
# =========
# RUN IS 31
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.568044	train's auc: 0.999799
# Early stopping, best iteration is:
# [1]	valid's auc: 0.6405	train's auc: 0.763936
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.56666	train's auc: 0.999267
# Early stopping, best iteration is:
# [20]	valid's auc: 0.625321	train's auc: 0.928716
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.607328	train's auc: 0.999408
# Early stopping, best iteration is:
# [21]	valid's auc: 0.645748	train's auc: 0.94199
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.598973	train's auc: 0.999559
# Early stopping, best iteration is:
# [110]	valid's auc: 0.605491	train's auc: 0.998567
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.566204	train's auc: 0.999024
# Early stopping, best iteration is:
# [7]	valid's auc: 0.595664	train's auc: 0.876415
#       fold     train     valid
# 0        0  0.763936  0.640500
# 1        1  0.928716  0.625321
# 2        2  0.941990  0.645748
# 3        3  0.998567  0.605491
# 4        4  0.876415  0.595664
# 5  overall  0.901925  0.605460
# =========
# RUN IS 32
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.596895	train's auc: 0.999607
# Early stopping, best iteration is:
# [9]	valid's auc: 0.651774	train's auc: 0.847318
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.61505	train's auc: 0.999909
# Early stopping, best iteration is:
# [28]	valid's auc: 0.667569	train's auc: 0.927726
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.616033	train's auc: 0.999945
# Early stopping, best iteration is:
# [77]	valid's auc: 0.6609	train's auc: 0.97159
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.627217	train's auc: 0.999924
# Early stopping, best iteration is:
# [37]	valid's auc: 0.662631	train's auc: 0.939247
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.593501	train's auc: 0.999838
# Early stopping, best iteration is:
# [30]	valid's auc: 0.653376	train's auc: 0.942994
#       fold     train     valid
# 0        0  0.847318  0.651774
# 1        1  0.927726  0.667569
# 2        2  0.971590  0.660900
# 3        3  0.939247  0.662631
# 4        4  0.942994  0.653376
# 5  overall  0.925775  0.657914
# =========
# RUN IS 33
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.594958	train's auc: 0.999988
# Early stopping, best iteration is:
# [3]	valid's auc: 0.630696	train's auc: 0.963019
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.653545	train's auc: 0.99999
# Early stopping, best iteration is:
# [19]	valid's auc: 0.632728	train's auc: 0.99999
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.598916	train's auc: 0.999989
# Early stopping, best iteration is:
# [18]	valid's auc: 0.553976	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.584495	train's auc: 0.999989
# Early stopping, best iteration is:
# [29]	valid's auc: 0.555402	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.611677	train's auc: 1
# Early stopping, best iteration is:
# [11]	valid's auc: 0.620211	train's auc: 0.999755
#       fold     train     valid
# 0        0  0.963019  0.630696
# 1        1  0.999990  0.632728
# 2        2  0.999989  0.553976
# 3        3  0.999989  0.555402
# 4        4  0.999755  0.620211
# 5  overall  0.992548  0.593931
# =========
# RUN IS 34
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.606419	train's auc: 0.999988
# Early stopping, best iteration is:
# [37]	valid's auc: 0.672479	train's auc: 0.998422
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.647442	train's auc: 0.99999
# Early stopping, best iteration is:
# [86]	valid's auc: 0.659056	train's auc: 0.999976
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.61877	train's auc: 0.999989
# Early stopping, best iteration is:
# [17]	valid's auc: 0.635996	train's auc: 0.986034
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.635552	train's auc: 0.999989
# Early stopping, best iteration is:
# [149]	valid's auc: 0.66348	train's auc: 0.999982
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.626381	train's auc: 1
# Early stopping, best iteration is:
# [92]	valid's auc: 0.658993	train's auc: 0.999918
#       fold     train     valid
# 0        0  0.998422  0.672479
# 1        1  0.999976  0.659056
# 2        2  0.986034  0.635996
# 3        3  0.999982  0.663480
# 4        4  0.999918  0.658993
# 5  overall  0.996866  0.634217
# =========
# RUN IS 35
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.538352	train's auc: 0.989063
# Early stopping, best iteration is:
# [35]	valid's auc: 0.665219	train's auc: 0.848696
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.568062	train's auc: 0.991447
# Early stopping, best iteration is:
# [9]	valid's auc: 0.669129	train's auc: 0.816223
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.599578	train's auc: 0.991891
# Early stopping, best iteration is:
# [17]	valid's auc: 0.686924	train's auc: 0.820525
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.606143	train's auc: 0.988879
# Early stopping, best iteration is:
# [23]	valid's auc: 0.697709	train's auc: 0.82269
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.559716	train's auc: 0.991851
# Early stopping, best iteration is:
# [3]	valid's auc: 0.667393	train's auc: 0.792619
#       fold     train     valid
# 0        0  0.848696  0.665219
# 1        1  0.816223  0.669129
# 2        2  0.820525  0.686924
# 3        3  0.822690  0.697709
# 4        4  0.792619  0.667393
# 5  overall  0.820151  0.674539
# =========
# RUN IS 36
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.596289	train's auc: 0.999757
# Early stopping, best iteration is:
# [2]	valid's auc: 0.627042	train's auc: 0.844347
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.659076	train's auc: 0.999799
# Early stopping, best iteration is:
# [34]	valid's auc: 0.66749	train's auc: 0.996403
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.641175	train's auc: 0.999447
# Early stopping, best iteration is:
# [20]	valid's auc: 0.668926	train's auc: 0.981201
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.667766	train's auc: 0.999681
# Early stopping, best iteration is:
# [14]	valid's auc: 0.698598	train's auc: 0.957654
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.627404	train's auc: 0.999889
# Early stopping, best iteration is:
# [7]	valid's auc: 0.666832	train's auc: 0.924114
#       fold     train     valid
# 0        0  0.844347  0.627042
# 1        1  0.996403  0.667490
# 2        2  0.981201  0.668926
# 3        3  0.957654  0.698598
# 4        4  0.924114  0.666832
# 5  overall  0.940744  0.656142
# =========
# RUN IS 37
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.631162	train's auc: 0.996897
# Early stopping, best iteration is:
# [5]	valid's auc: 0.648051	train's auc: 0.921675
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614438	train's auc: 0.998905
# Early stopping, best iteration is:
# [4]	valid's auc: 0.6452	train's auc: 0.915021
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.544665	train's auc: 0.999202
# Early stopping, best iteration is:
# [4]	valid's auc: 0.58618	train's auc: 0.909195
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.674521	train's auc: 0.997884
# Early stopping, best iteration is:
# [33]	valid's auc: 0.674521	train's auc: 0.99787
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.626113	train's auc: 0.998875
# Early stopping, best iteration is:
# [9]	valid's auc: 0.678694	train's auc: 0.968299
#       fold     train     valid
# 0        0  0.921675  0.648051
# 1        1  0.915021  0.645200
# 2        2  0.909195  0.586180
# 3        3  0.997870  0.674521
# 4        4  0.968299  0.678694
# 5  overall  0.942412  0.639660
# =========
# RUN IS 38
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614449	train's auc: 0.999988
# Early stopping, best iteration is:
# [25]	valid's auc: 0.632843	train's auc: 0.989899
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.620166	train's auc: 0.99999
# Early stopping, best iteration is:
# [4]	valid's auc: 0.672092	train's auc: 0.833517
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.57326	train's auc: 0.999989
# Early stopping, best iteration is:
# [8]	valid's auc: 0.663067	train's auc: 0.903975
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.645013	train's auc: 0.999989
# Early stopping, best iteration is:
# [21]	valid's auc: 0.665653	train's auc: 0.985425
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.628963	train's auc: 1
# Early stopping, best iteration is:
# [36]	valid's auc: 0.666806	train's auc: 0.999151
#       fold     train     valid
# 0        0  0.989899  0.632843
# 1        1  0.833517  0.672092
# 2        2  0.903975  0.663067
# 3        3  0.985425  0.665653
# 4        4  0.999151  0.666806
# 5  overall  0.942393  0.646276
# =========
# RUN IS 39
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.612722	train's auc: 0.999986
# Early stopping, best iteration is:
# [23]	valid's auc: 0.633894	train's auc: 0.997858
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.653466	train's auc: 0.99999
# Early stopping, best iteration is:
# [33]	valid's auc: 0.690638	train's auc: 0.999802
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.623379	train's auc: 0.999989
# Early stopping, best iteration is:
# [68]	valid's auc: 0.592121	train's auc: 0.999989
# ...
# [189]	valid's auc: 0.652558	train's auc: 0.998998
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.617293	train's auc: 0.999996
# Early stopping, best iteration is:
# [10]	valid's auc: 0.665046	train's auc: 0.907307
#       fold     train     valid
# 0        0  0.988397  0.647176
# 1        1  0.996486  0.672882
# 2        2  0.847769  0.671120
# 3        3  0.998998  0.652558
# 4        4  0.907307  0.665046
# 5  overall  0.947791  0.605507
# =========
# RUN IS 1455
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.575023	train's auc: 0.999976
# Early stopping, best iteration is:
# [6]	valid's auc: 0.651657	train's auc: 0.824234
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.63492	train's auc: 0.999988
# Early stopping, best iteration is:
# [231]	valid's auc: 0.675904	train's auc: 0.998346
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.619982	train's auc: 0.999987
# Early stopping, best iteration is:
# [17]	valid's auc: 0.679431	train's auc: 0.895482
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.630575	train's auc: 0.999982
# Early stopping, best iteration is:
# [72]	valid's auc: 0.684969	train's auc: 0.978301
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.580406	train's auc: 1
# Early stopping, best iteration is:
# [144]	valid's auc: 0.617864	train's auc: 0.994292
#       fold     train     valid
# 0        0  0.824234  0.651657
# 1        1  0.998346  0.675904
# 2        2  0.895482  0.679431
# 3        3  0.978301  0.684969
# 4        4  0.994292  0.617864
# 5  overall  0.938131  0.631425
# =========
# RUN IS 1456
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.521615	train's auc: 0.999988
# Early stopping, best iteration is:
# [6]	valid's auc: 0.590406	train's auc: 0.905225
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.580723	train's auc: 0.99999
# Early stopping, best iteration is:
# [2]	valid's auc: 0.610695	train's auc: 0.791566
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.591185	train's auc: 0.999989
# Early stopping, best iteration is:
# [1]	valid's auc: 0.618604	train's auc: 0.747583
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.611712	train's auc: 0.999989
# Early stopping, best iteration is:
# [51]	valid's auc: 0.619534	train's auc: 0.999984
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.566104	train's auc: 1
# Early stopping, best iteration is:
# [3]	valid's auc: 0.608977	train's auc: 0.830752
#       fold     train     valid
# 0        0  0.905225  0.590406
# 1        1  0.791566  0.610695
# 2        2  0.747583  0.618604
# 3        3  0.999984  0.619534
# 4        4  0.830752  0.608977
# 5  overall  0.855022  0.602416
# =========
# RUN IS 1457
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.523296	train's auc: 0.999988
# Early stopping, best iteration is:
# [5]	valid's auc: 0.680976	train's auc: 0.807699
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.5952	train's auc: 0.999988
# Early stopping, best iteration is:
# [26]	valid's auc: 0.680269	train's auc: 0.895652
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.588356	train's auc: 0.999987
# Early stopping, best iteration is:
# [61]	valid's auc: 0.626795	train's auc: 0.948468
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.588821	train's auc: 0.999989
# Early stopping, best iteration is:
# [8]	valid's auc: 0.636599	train's auc: 0.822859
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.533894	train's auc: 1
# Early stopping, best iteration is:
# [11]	valid's auc: 0.630456	train's auc: 0.848713
#       fold     train     valid
# 0        0  0.807699  0.680976
# 1        1  0.895652  0.680269
# 2        2  0.948468  0.626795
# 3        3  0.822859  0.636599
# 4        4  0.848713  0.630456
# 5  overall  0.864678  0.637660
# =========
# RUN IS 1458
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.610411	train's auc: 0.999988
# Early stopping, best iteration is:
# [4]	valid's auc: 0.63729	train's auc: 0.984934
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.627533	train's auc: 0.99999
# Early stopping, best iteration is:
# [18]	valid's auc: 0.600691	train's auc: 0.99999
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.621653	train's auc: 0.999972
# Early stopping, best iteration is:
# [22]	valid's auc: 0.604812	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.62775	train's auc: 0.999987
# Early stopping, best iteration is:
# [29]	valid's auc: 0.614616	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.599772	train's auc: 1
# Early stopping, best iteration is:
# [13]	valid's auc: 0.604333	train's auc: 0.999941
#       fold     train     valid
# 0        0  0.984934  0.637290
# 1        1  0.999990  0.600691
# 2        2  0.999989  0.604812
# 3        3  0.999989  0.614616
# 4        4  0.999941  0.604333
# 5  overall  0.996969  0.521247
# =========
# RUN IS 1459
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.563912	train's auc: 0.999431
# Early stopping, best iteration is:
# [20]	valid's auc: 0.564869	train's auc: 0.997816
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.58098	train's auc: 0.999803
# Early stopping, best iteration is:
# [2]	valid's auc: 0.643532	train's auc: 0.812614
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.638549	train's auc: 0.999778
# Early stopping, best iteration is:
# [13]	valid's auc: 0.666575	train's auc: 0.989185
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.5968	train's auc: 0.999497
# Early stopping, best iteration is:
# [25]	valid's auc: 0.597255	train's auc: 0.999352
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.537332	train's auc: 0.999966
# Early stopping, best iteration is:
# [1]	valid's auc: 0.596771	train's auc: 0.759182
#       fold     train     valid
# 0        0  0.997816  0.564869
# 1        1  0.812614  0.643532
# 2        2  0.989185  0.666575
# 3        3  0.999352  0.597255
# 4        4  0.759182  0.596771
# 5  overall  0.911630  0.606636
# =========
# RUN IS 1460
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.613445	train's auc: 0.999571
# Early stopping, best iteration is:
# [22]	valid's auc: 0.649603	train's auc: 0.889382
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.60393	train's auc: 0.999776
# Early stopping, best iteration is:
# [49]	valid's auc: 0.665673	train's auc: 0.946631
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.634564	train's auc: 0.999625
# Early stopping, best iteration is:
# [143]	valid's auc: 0.662994	train's auc: 0.984745
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.61584	train's auc: 0.999864
# Early stopping, best iteration is:
# [184]	valid's auc: 0.632036	train's auc: 0.991945
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.608876	train's auc: 0.999757
# Early stopping, best iteration is:
# [111]	valid's auc: 0.646753	train's auc: 0.982084
#       fold     train     valid
# 0        0  0.889382  0.649603
# 1        1  0.946631  0.665673
# 2        2  0.984745  0.662994
# 3        3  0.991945  0.632036
# 4        4  0.982084  0.646753
# 5  overall  0.958958  0.630356
# =========
# RUN IS 1461
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.596429	train's auc: 0.962693
# Early stopping, best iteration is:
# [13]	valid's auc: 0.623389	train's auc: 0.934251
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.66115	train's auc: 0.966328
# Early stopping, best iteration is:
# [43]	valid's auc: 0.654928	train's auc: 0.973927
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.602369	train's auc: 0.958948
# Early stopping, best iteration is:
# [8]	valid's auc: 0.636547	train's auc: 0.900234
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.645526	train's auc: 0.962052
# Early stopping, best iteration is:
# [14]	valid's auc: 0.671321	train's auc: 0.943375
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.641086	train's auc: 0.968018
# Early stopping, best iteration is:
# [115]	valid's auc: 0.631998	train's auc: 0.974025
#       fold     train     valid
# 0        0  0.934251  0.623389
# 1        1  0.973927  0.654928
# 2        2  0.900234  0.636547
# 3        3  0.943375  0.671321
# 4        4  0.974025  0.631998
# 5  overall  0.945162  0.538351
# =========
# RUN IS 1462
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.599463	train's auc: 0.999984
# Early stopping, best iteration is:
# [45]	valid's auc: 0.621639	train's auc: 0.949197
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.577582	train's auc: 0.99999
# Early stopping, best iteration is:
# [30]	valid's auc: 0.632155	train's auc: 0.913258
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.610909	train's auc: 0.999989
# Early stopping, best iteration is:
# [67]	valid's auc: 0.625528	train's auc: 0.967514
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.607229	train's auc: 0.999989
# Early stopping, best iteration is:
# [42]	valid's auc: 0.634841	train's auc: 0.937184
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.590969	train's auc: 1
# Early stopping, best iteration is:
# [71]	valid's auc: 0.636609	train's auc: 0.974791
#       fold     train     valid
# 0        0  0.949197  0.621639
# 1        1  0.913258  0.632155
# 2        2  0.967514  0.625528
# 3        3  0.937184  0.634841
# 4        4  0.974791  0.636609
# 5  overall  0.948389  0.626058
# =========
# RUN IS 1463
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.589776	train's auc: 0.999988
# Early stopping, best iteration is:
# [1]	valid's auc: 0.638177	train's auc: 0.770806
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.608947	train's auc: 0.99999
# Early stopping, best iteration is:
# [19]	valid's auc: 0.647482	train's auc: 0.996627
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.60314	train's auc: 0.999989
# Early stopping, best iteration is:
# [1]	valid's auc: 0.642241	train's auc: 0.772083
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.614833	train's auc: 0.999989
# Early stopping, best iteration is:
# [45]	valid's auc: 0.602232	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.599319	train's auc: 1
# Early stopping, best iteration is:
# [40]	valid's auc: 0.565802	train's auc: 1
#       fold     train     valid
# 0        0  0.770806  0.638177
# 1        1  0.996627  0.647482
# 2        2  0.772083  0.642241
# 3        3  0.999989  0.602232
# 4        4  1.000000  0.565802
# 5  overall  0.907901  0.576653
# =========
# RUN IS 1464
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.618721	train's auc: 0.999986
# Early stopping, best iteration is:
# [184]	valid's auc: 0.624556	train's auc: 0.999988
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.623919	train's auc: 0.99999
# Early stopping, best iteration is:
# [22]	valid's auc: 0.66194	train's auc: 0.994338
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.634307	train's auc: 0.999989
# Early stopping, best iteration is:
# [73]	valid's auc: 0.623122	train's auc: 0.999989
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.638594	train's auc: 0.999989
# Early stopping, best iteration is:
# [2]	valid's auc: 0.650158	train's auc: 0.857642
# Training until validation scores don't improve for 500 rounds.
# [500]	valid's auc: 0.604148	train's auc: 1
# Early stopping, best iteration is:
# [29]	valid's auc: 0.629701	train's auc: 0.998427
#       fold     train     valid
# 0        0  0.999988  0.624556
# 1        1  0.994338  0.661940
# 2        2  0.999989  0.623122
# 3        3  0.857642  0.650158
# 4        4  0.998427  0.629701
# 5  overall  0.970077  0.628989
# =========
# RUN IS 1465
# =========
# LGB starting
# Training until validation scores don't improve for 500 rounds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c540a1afaefc> in <module>
#      29                                                  params = random_params,
#      30                                                  eval_metric = 'auc',
# ---> 31                                                  early_stopping_rounds = 500)
#      32
#      33     temp_df = pd.DataFrame(columns=df_cols)
#
# ~/Desktop/YourMD/machine_learning/mimic/src/modeling/models.py in train_lgb(features, labels, n_folds, params, eval_metric, early_stopping_rounds)
#      47         model.fit(train_features, train_labels, eval_metric = 'auc',
#      48                   eval_set = [(valid_features, valid_labels), (train_features, train_labels)],
# ---> 49                   eval_names = ['valid', 'train'], early_stopping_rounds = 500, verbose=500)
#      50
#      51         # Record the best iteration
#
# ~/anaconda3/envs/mimic/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     698                                         verbose=verbose, feature_name=feature_name,
#     699                                         categorical_feature=categorical_feature,
# --> 700                                         callbacks=callbacks)
#     701         return self
#     702
#
# ~/anaconda3/envs/mimic/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     500                               verbose_eval=verbose, feature_name=feature_name,
#     501                               categorical_feature=categorical_feature,
# --> 502                               callbacks=callbacks)
#     503
#     504         if evals_result:
#
# ~/anaconda3/envs/mimic/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     211                                     evaluation_result_list=None))
#     212
# --> 213         booster.update(fobj=fobj)
#     214
#     215         evaluation_result_list = []
#
# ~/anaconda3/envs/mimic/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1753             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1754                 self.handle,
# -> 1755                 ctypes.byref(is_finished)))
#    1756             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1757             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
runs_df.sort_values(by='valid_score', ascending=False)
# Out:
#    boosting_type num_leaves learning_rate subsample_for_bin min_data_in_leaf  \
# 0           goss        143      0.184306            220000              151
# 0           goss        144      0.296327            200000              151
# 0           goss         40      0.316694             80000              190
# 0           goss         67      0.347245            100000              163
# 0           goss         51     0.0824694            220000              166
# 0           goss        126       0.11302            140000              199
# 0           goss        131      0.163939            100000              166
# 0           goss         27      0.123204             60000              196
# 0           goss         13      0.265776            260000              172
# 0           gbdt         74      0.235224            280000              196
# 0           goss        107     0.0824694             40000              160
# 0           goss        135      0.163939            180000              163
# 0           goss         24      0.235224             20000              175
# 0           goss         64      0.255592            220000              178
# 0           goss         41      0.245408             20000              169
# 0           goss        133      0.337061             80000              157
# 0           goss         93      0.438898            180000              172
# 0           goss         80      0.102837            180000              133
# 0           goss        103      0.031551             80000              193
# 0           goss         36     0.0519184            280000               79
# 0           goss        149     0.0824694             60000              172
# 0           goss         27      0.143571            220000              181
# 0           goss         87       0.30651             40000              181
# 0           goss        137      0.062102            100000              163
# 0           gbdt         56      0.123204            220000              142
# 0           goss         23     0.0417347            140000              187
# 0           goss        112      0.347245            220000              181
# 0           goss        112      0.174122            100000              148
# 0           gbdt         13      0.133388             40000              127
# 0           goss        116      0.174122             40000              133
# ..           ...        ...           ...               ...              ...
# 0           dart         85      0.469449            160000              193
# 0           dart         49     0.0722857             60000              196
# 0           dart        118      0.296327             80000              127
# 0           dart         58      0.133388            120000              112
# 0           dart        147     0.0824694             80000              118
# 0           dart         11      0.367612            120000               88
# 0           dart        141      0.265776            280000              112
# 0           dart         81       0.38798            200000              103
# 0           dart         36      0.479633             60000               91
# 0           dart         11      0.143571            100000              178
# 0           dart        117      0.337061            240000               70
# 0           dart         54      0.449082            200000              127
# 0           dart         77      0.255592            120000              160
# 0           dart        109      0.163939            280000              154
# 0           dart         80      0.326878             60000              151
# 0           dart         60      0.163939            220000               73
# 0           dart        108      0.286143             40000               91
# 0           dart         46      0.377796            260000              160
# 0           dart         70      0.408347             60000               88
# 0           dart         41      0.225041             20000              154
# 0           dart         46      0.265776             80000              112
# 0           dart        104      0.296327            140000              103
# 0           dart         98      0.275959            260000               31
# 0           dart        148      0.235224             20000              169
# 0           dart        144      0.469449            240000              127
# 0           dart         25      0.489816             40000               40
# 0           dart         21       0.11302            140000              121
# 0           dart         20      0.357429            240000              139
# 0           dart        147      0.143571            140000              133
# 0           dart        134      0.296327             80000              133
#
#     reg_alpha reg_lambda colsample_bytree subsample is_unbalance  \
# 0    0.204082    0.22449         0.204878  0.653061        False
# 0           0   0.877551         0.979612  0.663265        False
# 0     0.77551   0.142857         0.755347  0.571429        False
# 0    0.265306   0.428571          0.63302  0.744898        False
# 0    0.714286   0.857143         0.918449  0.846939        False
# 0    0.489796   0.591837         0.551469  0.714286        False
# 0    0.836735   0.387755          0.81651  0.795918        False
# 0    0.306122   0.265306         0.531082         1        False
# 0    0.836735   0.734694          0.63302  0.714286        False
# 0    0.857143   0.612245         0.510694  0.795918        False
# 0    0.979592   0.693878         0.571857  0.755102        False
# 0    0.387755   0.163265          0.63302  0.663265        False
# 0    0.938776    0.44898         0.123327  0.561224        False
# 0    0.142857  0.0408163         0.796122  0.571429        False
# 0    0.653061   0.163265         0.877673  0.897959        False
# 0    0.142857   0.938776          0.81651  0.887755        False
# 0    0.102041   0.612245         0.938837  0.683673        False
# 0    0.632653   0.612245         0.490306  0.591837        False
# 0    0.469388    0.44898         0.653408  0.765306         True
# 0   0.0612245    0.55102         0.755347  0.653061        False
# 0    0.428571   0.918367         0.164102  0.663265         True
# 0    0.877551   0.857143         0.531082  0.897959         True
# 0    0.653061   0.326531         0.592245  0.857143        False
# 0    0.183673   0.122449         0.673796  0.959184        False
# 0    0.265306   0.530612         0.592245  0.693878        False
# 0           1   0.326531         0.979612   0.72449        False
# 0    0.877551    0.44898         0.796122  0.693878        False
# 0    0.755102   0.979592                1  0.959184        False
# 0    0.244898   0.755102         0.979612  0.857143        False
# 0    0.265306   0.673469         0.938837  0.520408        False
# ..        ...        ...              ...       ...          ...
# 0    0.163265   0.734694         0.245653  0.846939        False
# 0    0.571429  0.0408163         0.449531  0.653061        False
# 0    0.326531    0.77551          0.81651  0.938776        False
# 0    0.795918   0.530612         0.449531  0.918367        False
# 0     0.77551   0.489796         0.469918   0.77551        False
# 0    0.877551   0.530612         0.857286  0.826531        False
# 0           1   0.306122         0.612633  0.765306        False
# 0     0.55102    0.22449         0.266041  0.755102        False
# 0    0.734694   0.918367         0.836898  0.632653        False
# 0     0.22449   0.673469         0.551469  0.979592        False
# 0    0.836735   0.122449         0.673796  0.928571        False
# 0    0.897959   0.469388         0.531082  0.897959        False
# 0    0.591837   0.959184         0.408755  0.663265        False
# 0    0.367347   0.693878         0.714571  0.673469        False
# 0    0.571429          0         0.102939  0.897959        False
# 0    0.591837    0.55102         0.306816  0.887755        False
# 0    0.306122   0.428571            0.001  0.989796        False
# 0    0.510204    0.55102         0.164102   0.72449        False
# 0    0.877551   0.510204          0.18449  0.530612        False
# 0    0.428571   0.346939         0.551469   0.55102        False
# 0    0.632653   0.836735         0.102939  0.571429        False
# 0    0.979592  0.0816327         0.979612  0.510204        False
# 0    0.918367   0.408163        0.0213878  0.765306        False
# 0    0.510204          1         0.164102  0.653061        False
# 0    0.816327   0.102041         0.898061  0.714286        False
# 0    0.408163   0.979592         0.571857  0.591837        False
# 0    0.612245   0.387755         0.714571  0.969388        False
# 0    0.387755   0.979592         0.531082  0.744898        False
# 0    0.632653   0.673469         0.571857  0.908163        False
# 0    0.938776   0.326531         0.612633   0.94898        False
#
#    min_split_gain training_score valid_score
# 0        0.755347       0.813497     0.68011
# 0        0.612633        0.82766    0.679706
# 0        0.225265       0.823133     0.67908
# 0        0.286429       0.800701    0.677386
# 0        0.938837       0.832606    0.676849
# 0         0.36798       0.803886    0.676848
# 0       0.0621633       0.838252    0.676478
# 0        0.551469       0.807165    0.676352
# 0           0.001         0.8039    0.675718
# 0        0.388367        0.86011    0.675541
# 0        0.490306       0.835798    0.675276
# 0        0.388367       0.826948    0.675059
# 0       0.0621633       0.803408    0.674977
# 0        0.225265       0.821918    0.674967
# 0        0.408755       0.820151    0.674539
# 0        0.245653       0.823663    0.674218
# 0        0.286429       0.785818    0.673905
# 0               1       0.834947    0.673855
# 0        0.796122       0.871853    0.673738
# 0        0.694184       0.924688    0.673475
# 0       0.0621633       0.855296    0.673435
# 0        0.429143        0.85424    0.673194
# 0        0.266041       0.814305    0.673141
# 0        0.408755       0.842915    0.673124
# 0        0.877673       0.833055    0.673103
# 0        0.836898       0.831846    0.673081
# 0        0.429143       0.793774    0.673076
# 0        0.123327       0.835311    0.672894
# 0        0.755347       0.845696    0.672501
# 0        0.898061       0.844672    0.672492
# ..            ...            ...         ...
# 0        0.836898       0.837105    0.478674
# 0        0.612633       0.853442    0.478406
# 0        0.531082        0.83363    0.477275
# 0         0.36798       0.929809    0.476533
# 0        0.327204       0.909359    0.474765
# 0         0.81651       0.847398    0.473849
# 0       0.0417755       0.910265    0.473812
# 0        0.653408       0.962402    0.472441
# 0        0.551469       0.896217    0.469504
# 0        0.734959       0.864549     0.46934
# 0        0.245653       0.929112    0.469219
# 0        0.327204        0.87766    0.469145
# 0        0.388367       0.910216    0.468257
# 0        0.510694       0.910332    0.467878
# 0        0.918449       0.856708    0.466578
# 0        0.449531       0.932748    0.466316
# 0        0.469918       0.811118    0.463617
# 0         0.63302       0.900044    0.463566
# 0        0.877673       0.909404    0.462338
# 0       0.0417755       0.851898    0.462101
# 0        0.612633       0.891091    0.459821
# 0        0.836898       0.887143     0.45744
# 0        0.571857       0.850152    0.456113
# 0        0.306816       0.855832    0.453744
# 0        0.266041       0.859329     0.45323
# 0        0.306816       0.889112     0.45067
# 0        0.082551       0.867148    0.450109
# 0        0.898061       0.820599    0.434671
# 0        0.612633        0.87526    0.432912
# 0        0.286429       0.848238     0.39159
#
# [1464 rows x 13 columns]

# %%
runs_df.columns.tolist()
# Out:
# ['boosting_type',
#  'num_leaves',
#  'learning_rate',
#  'subsample_for_bin',
#  'min_data_in_leaf',
#  'reg_alpha',
#  'reg_lambda',
#  'colsample_bytree',
#  'subsample',
#  'is_unbalance',
#  'min_split_gain',
#  'training_score',
#  'valid_score']

# %%
sns.scatterplot(runs_df['training_score'], runs_df['valid_score'])
